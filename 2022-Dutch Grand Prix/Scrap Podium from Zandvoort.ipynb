# %% [markdown]
# # Code to extract the winner in Dutch GP in Zandvoort

# %% [markdown]
# This code is created to make a DataFrame with the winners of the Dutch Grand Prix in Zandvoort. The data is taken from the page of pitwall.app

# %% [markdown]
# ## Setup

# %% [markdown]
# Let's load some libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Code

# %% [markdown]
# The following code will scrap from the pitwall.app to create a DataFrame with the winners of the Dutch Grand Prix

# %%
read_data = pd.read_html('https://pitwall.app/races/2021-dutch-grand-prix')
results = read_data[0].drop(columns=['Pos','Pts'])
year = 2021
winner = results.loc[[0]].assign(Year=year)
winner.insert(5, column='Delta', value=float(results.iat[1,2].strip('+')))
winner_year = winner.set_index('Year')
i = 1
while i < 75:
    year = year-1
    print(year)
    if year == 2020:
        year = 1985
    elif year == 1951:
        break
    url = str(year)
    url = 'https://pitwall.app/races/'+ url + '-dutch-grand-prix'
    try:
        read_data = pd.read_html(url)
    except:
        i += 1
        continue
    results = read_data[0].drop(columns=['Pos','Pts'])
    winner = results.loc[[0]].assign(Year=year)
    winner = winner.set_index('Year')
    try:
        winner.insert(5, column='Delta', value=float(results.iat[1,2].strip('+')))
    except:
        winner.insert(5, column='Delta', value=0)
    winner_year = pd.concat([winner_year,winner], axis=0)
    i += 1
winner_year['Driver'] = [x.split(' ', 1)[1].strip() for x in list(winner_year['Driver'])]
winner_year
# Out:
# 2020
# 1984
# 1983
# 1982
# 1981
# 1980
# 1979
# 1978
# 1977
# 1976
# 1975
# 1974
# 1973
# 1972
# 1971
# 1970
# 1969
# 1968
# 1967
# 1966
# 1965
# 1964
# 1963
# 1962
# 1961
# 1960
# 1959
# 1958
# 1957
# 1956
# 1955
# 1954
# 1953
# 1952
# 1951
#                   Driver            Car Time/Retired  Grid  Laps   Delta
# Year
# 2021      Max Verstappen       Red Bull  1:30:05.395     1    72  20.932
# 1985          Niki Lauda        McLaren  1:32:29.263    10    70   0.232
# 1984         Alain Prost        McLaren  1:37:21.468     1    71  10.283
# 1983        Ren̩ Arnoux        Ferrari  1:38:41.950    10    72  20.839
# 1982       Didier Pironi        Ferrari  1:38:03.254     4    72  21.649
# 1981         Alain Prost        Renault   1:40:22.43     1    72   8.240
# 1980       Nelson Piquet        Brabham   1:38:13.83     5    72  12.930
# 1979          Alan Jones       Williams  1:41:19.775     2    75  21.783
# 1978      Mario Andretti     Team Lotus   1:41:04.23     1    75   0.320
# 1977          Niki Lauda        Ferrari   1:41:45.93     4    75   1.890
# 1976          James Hunt        McLaren   1:44:52.09     2    75   0.920
# 1975          James Hunt        Hesketh   1:46:57.40     3    75   1.060
# 1974          Niki Lauda        Ferrari   1:43:00.35     1    75   8.250
# 1973      Jackie Stewart        Tyrrell   1:39:12.45     2    72  15.830
# 1971          Jacky Ickx        Ferrari    1:56:20.0     1    70   7.990
# 1970        Jochen Rindt     Team Lotus    1:50:43.4     1    80  30.000
# 1969      Jackie Stewart     Matra-Ford   2:06:42.08     2    90  24.520
# 1968      Jackie Stewart     Matra-Ford    2:46:11.2     5    90   0.000
# 1967           Jim Clark     Lotus-Ford    2:14:45.1     8    90  23.600
# 1966        Jack Brabham  Brabham-Repco    2:20:32.5     1    90   0.000
# 1965           Jim Clark   Lotus-Climax    2:03:59.1     2    80   8.000
# 1964           Jim Clark   Lotus-Climax    2:07:35.4     2    80  53.600
# 1963           Jim Clark   Lotus-Climax    2:08:13.7     1    80   0.000
# 1962         Graham Hill            BRM    2:11:02.1     2    80  27.200
# 1961  Wolfgang von Trips        Ferrari    2:01:52.1     2    75   0.900
# 1960        Jack Brabham  Cooper-Climax    2:01:47.2     2    75  24.000
# 1959          Jo Bonnier            BRM    2:05:26.8     1    75  14.200
# 1958       Stirling Moss        Vanwall    2:04:49.2     2    75  47.900
# 1955         Juan Fangio       Mercedes    2:54:23.8     1   100   0.300
# 1953      Alberto Ascari        Ferrari    2:53:35.8     1    90  10.400
# 1952      Alberto Ascari        Ferrari    2:53:28.5     1    90  40.100

# %%
winner_year.to_csv('Winner from Dutch Grand Prix.csv')
