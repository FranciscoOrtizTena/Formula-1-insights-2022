# %% [markdown]
# # Code to extract data Qualy in Italian Grand Prix

# %% [markdown]
# The following code create a DataFrame with the pole winner of the Qualifying in the Italian Grand Prix from 2006

# %% [markdown]
# ## Setup

# %% [markdown]
# First lets load some useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# ## Code

# %% [markdown]
# The data is taken from the page pitwall.app

# %%
read_data = pd.read_html('https://pitwall.app/races/2021-italian-grand-prix')
results = read_data[2].drop(columns=['Pos'])
results.loc[[0],['Delta']] = results.iat[1,5]
year = 2021
poleman = results.loc[[0]].assign(Year=year)
poleman_year = poleman.set_index('Year')
i = 1
while i < 20:
    print(year)
    year = year-1
    if year == 2005:
        break
    url = str(year)
    url = 'https://pitwall.app/races/'+ url + '-italian-grand-prix'
    try:
        read_data = pd.read_html(url)
    except:
        i += 1
        continue
    results = read_data[1].drop(columns=['Pos'])
    results.loc[[0],['Delta']] = results.iat[1,5]
    poleman = results.loc[[0]].assign(Year=year)
    poleman = poleman.set_index('Year')
    poleman_year = pd.concat([poleman_year,poleman], axis=0)
    i += 1
poleman_year
# Out:
# 2021
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
#                      Driver         Car        Q1        Q2        Q3  Delta
# Year
# 2021   #77  Valtteri Bottas    Mercedes  1:20.685  1:20.032  1:19.555  0.096
# 2020    #44  Lewis Hamilton    Mercedes  1:19.514  1:19.092  1:18.887  0.069
# 2019   #16  Charles Leclerc     Ferrari  1:20.126  1:19.553  1:19.307  0.039
# 2018   #7  Kimi RÃ¤ikkÃ¶nen     Ferrari  1:20.722  1:19.846  1:19.119  0.161
# 2017    #44  Lewis Hamilton    Mercedes  1:36.009  1:34.660  1:35.554  1.148
# 2016    #44  Lewis Hamilton    Mercedes  1:21.854  1:21.498  1:21.135  0.478
# 2015    #44  Lewis Hamilton    Mercedes  1:24.251  1:23.383  1:23.397  0.234
# 2014    #44  Lewis Hamilton    Mercedes  1:25.363  1:24.560  1:24.109  0.274
# 2013   #1  Sebastian Vettel    Red Bull  1:24.319  1:23.977  1:23.755  0.213
# 2012     #4  Lewis Hamilton     McLaren  1:24.211  1:24.394  1:24.010  0.123
# 2011   #1  Sebastian Vettel    Red Bull  1:24.002  1:22.914  1:22.275  0.450
# 2010    #8  Fernando Alonso     Ferrari  1:22.646  1:22.297  1:21.962  0.122
# 2009     #1  Lewis Hamilton     McLaren  1:23.375  1:22.973  1:24.066  0.195
# 2008  #15  Sebastian Vettel  Toro Rosso  1:35.464  1:35.837  1:37.555  0.076
# 2007    #1  Fernando Alonso     McLaren  1:21.718  1:21.356  1:21.997  0.037
# 2006   #3  Kimi RÃ¤ikkÃ¶nen     McLaren  1:21.994  1:21.349  1:21.484  0.002

# %%
poleman_year.to_csv('poleman Italien GP Qualy.csv')
