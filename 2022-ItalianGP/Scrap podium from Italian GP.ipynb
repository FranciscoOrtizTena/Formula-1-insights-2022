# %% [markdown]
# # Code to extract the podium data from Dutch GP

# %% [markdown]
# The following code gives you the list of drivers on the Podium from the Dutch Grand Prix in the circuit of Zandvoort, the info is taken from the web piwall.app

# %% [markdown]
# ## Setup

# %% [markdown]
# First let's load some libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Code

# %% [markdown]
# This will be the 32th race in the circuit of Zandvoort, so the following code will put all the drivers in the Podium information in one DataFrame

# %%
read_data = pd.read_html('https://pitwall.app/races/2021-italian-grand-prix')
results = read_data[0].drop(columns=['Pts','Time/Retired','Grid','Laps'])
year = 2021
winner = results.loc[[0,1,2]].assign(Year=year)
winner_pod = winner.set_index('Year')
i = 1
while i < 75:
    year = year-1
    print(year)
    if year == 1949:
        break
    url = str(year)
    url = 'https://pitwall.app/races/'+ url + '-italian-grand-prix'
    try:
        read_data = pd.read_html(url)
    except:
        i += 1
        continue
    results = read_data[0].drop(columns=['Pts','Time/Retired','Grid','Laps'])
    winner = results.loc[[0,1,2]].assign(Year=year)
    winner = winner.set_index('Year')
    winner_pod = pd.concat([winner_pod,winner], axis=0)
    i += 1
winner_pod['Pos'] = [int(x[0]) for x in list(winner_pod['Pos'])]
winner_pod['Driver'] = [x.split(' ', 1)[1].strip() for x in list(winner_pod['Driver'])]
winner_pod
# Out:
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
# 2005
# 2004
# 2003
# 2002
# 2001
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# 1990
# 1989
# 1988
# 1987
# 1986
# 1985
# 1984
# 1983
# 1982
# 1981
# 1980
# 1979
# 1978
# 1977
# 1976
# 1975
# 1974
# 1973
# 1972
# 1971
# 1970
# 1969
# 1968
# 1967
# 1966
# 1965
# 1964
# 1963
# 1962
# 1961
# 1960
# 1959
# 1958
# 1957
# 1956
# 1955
# 1954
# 1953
# 1952
# 1951
# 1950
# 1949
#       Pos                    Driver         Car
# Year
# 2021    1          Daniel Ricciardo     McLaren
# 2021    2              Lando Norris     McLaren
# 2021    3           Valtteri Bottas    Mercedes
# 2020    1              Pierre Gasly  AlphaTauri
# 2020    2              Carlos Sainz     McLaren
# ...   ...                       ...         ...
# 1951    2  JosÃ© FroilÃ¡n GonzÃ¡lez     Ferrari
# 1951    3            Felice Bonetto  Alfa Romeo
# 1950    1               Nino Farina  Alfa Romeo
# 1950    2            Alberto Ascari     Ferrari
# 1950    2           Dorino Serafini     Ferrari
#
# [216 rows x 3 columns]

# %% [markdown]
# Finally let's save it into a CSV file to work on Tableau

# %%
winner_pod.to_csv('Drivers Podium Dutch GP.csv')
