# %% [markdown]
# # Code to extract podiums in Italian GP in Autodromo Nazionale di Monza

# %% [markdown]
# This code is created to make a DataFrame with the podiums of the Italian Grand Prix in Autodromo Nazionale di Monza. The data is taken from the page of pitwall.app

# %% [markdown]
# ## Setup

# %% [markdown]
# Let's load some libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Code

# %% [markdown]
# The following code will scrap from the pitwall.app to create a DataFrame with the winners of the Italian Grand Prix

# %%
read_data = pd.read_html('https://pitwall.app/races/2021-italian-grand-prix')
results = read_data[0].drop(columns=['Pos','Pts'])
year = 2021
winner = results.loc[[0]].assign(Year=year)
winner.insert(5, column='Delta', value=float(results.iat[1,2].strip('+')))
winner_year = winner.set_index('Year')
i = 1
while i < 75:
    year = year-1
    print(year)
    if year == 1949:
        break
    url = str(year)
    url = 'https://pitwall.app/races/'+ url + '-italian-grand-prix'
    try:
        read_data = pd.read_html(url)
    except:
        i += 1
        continue
    results = read_data[0].drop(columns=['Pos','Pts'])
    winner = results.loc[[0]].assign(Year=year)
    winner = winner.set_index('Year')
    try:
        winner.insert(5, column='Delta', value=float(results.iat[1,2].strip('+')))
    except:
        winner.insert(5, column='Delta', value=0)
    winner_year = pd.concat([winner_year,winner], axis=0)
    i += 1
winner_year['Driver'] = [x.split(' ', 1)[1].strip() for x in list(winner_year['Driver'])]
winner_year
# Out:
# 2020
# 2019
# 2018
# 2017
# 2016
# 2015
# 2014
# 2013
# 2012
# 2011
# 2010
# 2009
# 2008
# 2007
# 2006
# 2005
# 2004
# 2003
# 2002
# 2001
# 2000
# 1999
# 1998
# 1997
# 1996
# 1995
# 1994
# 1993
# 1992
# 1991
# 1990
# 1989
# 1988
# 1987
# 1986
# 1985
# 1984
# 1983
# 1982
# 1981
# 1980
# 1979
# 1978
# 1977
# 1976
# 1975
# 1974
# 1973
# 1972
# 1971
# 1970
# 1969
# 1968
# 1967
# 1966
# 1965
# 1964
# 1963
# 1962
# 1961
# 1960
# 1959
# 1958
# 1957
# 1956
# 1955
# 1954
# 1953
# 1952
# 1951
# 1950
# 1949
#                 Driver         Car Time/Retired  Grid  Laps   Delta
# Year
# 2021  Daniel Ricciardo     McLaren  1:21:54.365     2    53   1.747
# 2020      Pierre Gasly  AlphaTauri  1:47:06.056    10    53   0.415
# 2019   Charles Leclerc     Ferrari  1:15:26.665     1    53   0.835
# 2018    Lewis Hamilton    Mercedes  1:16:54.484     3    53   8.705
# 2017    Lewis Hamilton    Mercedes  1:15:32.312     1    53   4.471
# ...

# %%
winner_year.to_csv('Winner from Italian Grand Prix.csv')
